# %%
##
## RECURSIVE META PROMPTING
##

from _pipeline import create_payload, model_req


MESSAGE = "AI Chatbot requirement analysis"

PROMPT = f"""
Generate a meta prompt that would instruct an AI to create a structured prompt for {MESSAGE}. Then, use that structured prompt to generate an actual article.
"""

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="open-webui",
                         model="Llama-3.2-3B-Instruct", 
                         prompt=PROMPT, 
                         temperature=1.0, 
                         num_ctx=100, 
                         num_predict=100)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'Llama-3.2-3B-Instruct', 'messages': [{'role': 'user', 'content': '\nGenerate a meta prompt that would instruct an AI to create a structured prompt for AI Chatbot requirement analysis. Then, use that structured prompt to generate an actual article.\n'}]}
# Meta Prompt:
#
# "Design a structured prompt to guide an AI chatbot in conducting a comprehensive requirement analysis for a new intelligent customer service platform. The prompt should elicit detailed information on the platform's purpose, target audience, functional requirements, non-functional requirements, and user experience considerations. Ensure the prompt is concise, clear, and free of ambiguity. Generate a structured article in the format of a research paper outline, with sections for each of the mentioned requirements and a clear introduction and conclusion."
#
# Here's the structured article:
#
# **Title:** Requirement Analysis for a New Intelligent Customer Service Platform
#
# **I. Introduction**
#
# ...
